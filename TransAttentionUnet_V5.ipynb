# %%
import os
import numpy as np
import pandas as pd
import rasterio
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Activation, Conv2DTranspose, concatenate, UpSampling2D, Concatenate, LayerNormalization, MultiHeadAttention, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Layer, Input, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer, Conv2D, BatchNormalization, Activation, UpSampling2D, Add
from tensorflow.keras.models import Sequential
import tensorflow.keras.backend as K
from tensorflow.keras.utils import Sequence
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import joblib
from scipy.ndimage import rotate
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.metrics import Precision, Recall
import tifffile
import random
import logging
from datetime import datetime
from tensorflow.keras import layers, models
from contextlib import redirect_stdout

# Suppress informational messages and warnings (but not errors)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0 = all messages are logged, 1 = INFO messages are not printed, 2 = INFO and WARNING messages are not printed, 3 = INFO, WARNING, and ERROR messages are not printed

tf.get_logger().setLevel('ERROR')  # This suppresses TensorFlow INFO and WARNING messages in Python

#데이터 설정
MAX_PIXEL_VALUE = 65535 # 이미지 정규화를 위한 픽셀 최대값
LEARNING_RATE_DECAY = 1

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Parameter

# %%
# 저장 이름
save_name = 'V4-P'

N_FILTERS = 16 # 필터수 지정
N_CHANNELS = 10 # channel 지정
EPOCHS = 30 # 훈련 epoch 지정
BATCH_SIZE = 64 # batch size 지정
IMAGE_SIZE = (256, 256) # 이미지 크기 지정
MODEL_NAME = 'swinT' # 모델 이름
INITIAL_EPOCH = 0 # 초기 epoch
WORKERS = 64
LEARNING_RATE_DECAY = 0.90
START_LARNING_RATE = 0.01
FINAL_SPARSITY = 0.3

#---------new--------------
AUGMENT = True
#--------------------------

LOSS = 'dice+bc'  # 'dice' , 'focal' , 'tversky' , 'binary_crossentropy' , 'dice+bc' -> 파라미터는 아래서 조정

#---------new--------------
# 모델 파라미터 정의
input_shape = (256, 256, 10)
initial_channels = 64
dim = 64
num_heads = 8
THRESHOLD = 0.5 # 고정값 -> 7번 channel 임계값
#--------------------------

EARLY_STOP_PATIENCE = 5 # 조기종료
CHECKPOINT_PERIOD = 5 # 중간 가중치 저장 이름

# 난수 시드 고정
SEED = 17
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)


# 사용할 데이터의 meta정보 가져오기
train_meta = pd.read_csv('/home/jskim/aispark/AIspark_dataset/train_meta.csv')
test_meta = pd.read_csv('/home/jskim/aispark/AIspark_dataset/test_meta.csv')
# 데이터 위치
IMAGES_PATH = '/home/jskim/aispark/AIspark_dataset/train_img'
MASKS_PATH = '/home/jskim/aispark/AIspark_dataset/train_mask'
# 가중치 저장 위치
OUTPUT_DIR = '/home/jskim/aispark/train_output/'

CHECKPOINT_MODEL_NAME = 'checkpoint-{}-{}-epoch_{{epoch:02d}}.hdf5'.format(MODEL_NAME, save_name)

# 최종 가중치 저장 이름
FINAL_WEIGHTS_OUTPUT = 'model_{}_{}_final_weights.h5'.format(MODEL_NAME, save_name)

# 기본 로그 디렉토리 설정
LOG_DIR = './logs/'

# 로그 파일 이름을 현재 시간으로 설정
log_filename = os.path.join(LOG_DIR, datetime.now().strftime('%Y-%m-%d_%H-%M-%S') + '_' + save_name + '_' + MODEL_NAME + '.log')

# 로깅 기본 설정
logging.basicConfig(filename=log_filename, level=logging.INFO, format='%(asctime)s:%(levelname)s:%(message)s')


# 저장 폴더 없으면 생성
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# 사용할 GPU 이름
CUDA_DEVICE = 1
# GPU 설정
os.environ["CUDA_VISIBLE_DEVICES"] = str(CUDA_DEVICE)
try:
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.compat.v1.Session(config=config)
    K.set_session(sess)
except:
    pass

try:
    np.random.bit_generator = np.random._bit_generator
except:
    pass
# Out:
# 2024-03-24 05:10:07.176546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12591 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:61:00.0, compute capability: 8.9

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Encoder structure

# %%
class EMSABlock(tf.keras.layers.Layer):
    def __init__(self, dim, num_heads, channel):
        super(EMSABlock, self).__init__()
        self.dim = dim
        self.num_heads = num_heads
        self.channel = channel  # 입력 텐서의 채널 수
        self.depthwise_conv = layers.DepthwiseConv2D(kernel_size=1, padding='same')
        self.layer_norm = layers.LayerNormalization(epsilon=1e-6)

        self.qkv = layers.Dense(dim * 3, use_bias=False)
        self.reshape = layers.Reshape((-1, num_heads, dim // num_heads))
        self.transpose = layers.Permute((2, 1, 3))
        
        self.fc = layers.Dense(self.channel)  # 여기서 self.channel은 입력의 채널 수와 동일해야 합니다.


        self.mlp = models.Sequential([
            layers.Dense(dim * 4, activation='relu'),
            layers.Dense(self.channel),
        ])

    def call(self, inputs):
        # Depthwise Convolution and Layer Norm
        x = self.depthwise_conv(inputs)
        x = self.layer_norm(x)
        
        # Generating q, k, v
        qkv = self.qkv(x)
        q, k, v = tf.split(qkv, 3, axis=-1)
        q = self.transpose(self.reshape(q))
        k = self.transpose(self.reshape(k))
        v = self.transpose(self.reshape(v))
        
        # Attention with MatMul
        attn_output = tf.matmul(q, k, transpose_b=True)
        attn_output = tf.nn.softmax(attn_output)
        attn_output = tf.matmul(attn_output, v)

        # attn_output을 원래 입력 형태로 다시 reshape 합니다.
        batch_size = tf.shape(inputs)[0]
        seq_len = tf.shape(inputs)[1]
        channel = tf.shape(inputs)[3]
        attn_output = tf.reshape(attn_output, [batch_size, seq_len, seq_len, channel])
        
        # Skip connection
        attn_output = self.fc(attn_output) + inputs

        # MLP with Skip connection
        mlp_output = self.mlp(attn_output) + attn_output
        
        return mlp_output

def create_stem_layer(input_shape):
    model = Sequential()
    
    # 첫 번째 Conv2D와 MaxPooling2D를 통해 H/2, W/2의 축소를 수행
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
    # 두 번째 Conv2D와 MaxPooling2D를 통해 H/4, W/4의 축소를 수행
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
    return model

class PositionalEmbedding2D(tf.keras.layers.Layer):
    def __init__(self, scale=0.1):
        super(PositionalEmbedding2D, self).__init__()
        self.scale = scale

    def build(self, input_shape):
        # `input_shape` 파라미터는 입력 텐서의 형태를 나타냅니다.
        # 이 형태에 기반하여 올바른 차원의 포지셔널 임베딩을 생성합니다.
        height, width, channels = input_shape[1], input_shape[2], input_shape[3]
        self.pos_emb = self.add_weight(
            name="pos_emb", 
            shape=(1, height, width, channels), 
            initializer="random_normal"  # 초기화 방식을 'random_normal'로 변경
        )

    def call(self, inputs):
        # 입력 텐서에 포지셔널 임베딩을 더해 반환합니다.
        return inputs + self.scale * self.pos_emb

def create_downsampling_and_positional_embedding(input_shape, filters):
    model = Sequential()
    # Downsampling
    model.add(Conv2D(filters, kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu'))
    # Positional Embedding. 여기서는 scale 매개변수만을 사용하면 됩니다.
    # 입력 형태는 build 또는 call 메소드가 호출될 때 자동으로 처리됩니다.
    model.add(PositionalEmbedding2D(scale=0.1))
    return model

def create_e_transformer_block(channels, num_heads):
    # Adjusted to pass `channels`
    e_transformer_block = models.Sequential()
    e_transformer_block.add(EMSABlock(dim, num_heads, channels))
    e_transformer_block.add(EMSABlock(dim, num_heads, channels))
    return e_transformer_block

def create_stage(input_tensor, input_channels, dim, num_heads):
    # This function now takes an input tensor and returns an output tensor.
    stage = tf.keras.Sequential()
    stage.add(PositionalEmbedding2D(input_channels))
    stage.add(create_e_transformer_block(dim, num_heads))
    stage.add(create_e_transformer_block(dim, num_heads))
    return stage(input_tensor)


'''
stage1 : (None, 64, 64, 64)
stage2 : (None, 32, 32, 128)
stage3 : (None, 16, 16, 256)
stage4 : (None, 8, 8, 512)
'''
# Out:
# '\nstage1 : (None, 64, 64, 64)\nstage2 : (None, 32, 32, 128)\nstage3 : (None, 16, 16, 256)\nstage4 : (None, 8, 8, 512)\n'

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Decoder structure

# %%
def MLPBlock(filters, input_tensor):
    # Define an MLP block to be used in the decoder after each fusion
    mlp = models.Sequential([
        layers.Dense(filters, use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('gelu'),
        layers.Dense(filters, use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('gelu')
    ], name='MLPBlock')
    return mlp(input_tensor)

def FlattenMLPReshape(filters, input_tensor):
    # Flatten, process through an MLP block and reshape for upsampling
    flattened = layers.Flatten()(input_tensor)
    mlp_output = MLPBlock(filters, flattened)
    # Reshape back to a 4D tensor. Note that the shape will be inferred.
    reshaped = layers.Reshape((input_tensor.shape[1] * 2, input_tensor.shape[2] * 2, filters))(mlp_output)
    return reshaped

class PyramidPoolingModule(Layer):
    def __init__(self, bin_sizes, **kwargs):
        super(PyramidPoolingModule, self).__init__(**kwargs)
        self.bin_sizes = bin_sizes

    def build(self, input_shape):
        self.convs = []
        for bin_size in self.bin_sizes:
            self.convs.append(Sequential([
                Conv2D(input_shape[-1], kernel_size=(1, 1), strides=(1, 1), padding='same'),
                BatchNormalization(),
                Activation('relu')
            ]))

    def call(self, inputs):
        concat_list = [inputs]
        h = inputs.shape[1]
        w = inputs.shape[2]
        for bin_size, conv in zip(self.bin_sizes, self.convs):
            x = tf.keras.layers.AveragePooling2D(pool_size=(h // bin_size, w // bin_size))(inputs)
            x = conv(x)
            x = UpSampling2D(size=(h // x.shape[1], w // x.shape[2]))(x)
            concat_list.append(x)
        return Concatenate()(concat_list)

def create_decoder(C1, C2, C3, C4):
    # PPM을 사용한 후 채널 수 조정을 위해 1x1 컨볼루션 레이어를 적용
    ppm = PyramidPoolingModule(bin_sizes=[1, 2, 3, 6])(C4)
    ppm = Conv2D(256, kernel_size=(1, 1), padding='same')(ppm)  # C3와 채널 수 일치
    upsampled_ppm = UpSampling2D(size=(2, 2))(ppm)
    
    # C3와 결합
    P3 = Add()([upsampled_ppm, C3])
    upsampled_P3 = UpSampling2D(size=(2, 2))(P3)
    
    # C2와 결합하기 전에 C2의 채널 수를 맞춥니다.
    C2_adjusted = Conv2D(256, kernel_size=(1, 1), padding='same')(C2)
    P2 = Add()([upsampled_P3, C2_adjusted])
    upsampled_P2 = UpSampling2D(size=(2, 2))(P2)
    
    # C1과 결합하기 전에 C1의 채널 수를 맞춥니다.
    C1_adjusted = Conv2D(256, kernel_size=(1, 1), padding='same')(C1)
    P1 = Add()([upsampled_P2, C1_adjusted])

    # 컨볼루션을 적용하여 최종 세그멘테이션 맵 생성
    segmentation_map = Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(P1)

    return segmentation_map

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### dataset , metric

# %%
def edge_enhancement(original_image, segmentation_result):
    # 원본 이미지에서 7번째 채널을 선택합니다.
    channel_7 = original_image[..., 6:7]  # 0-indexed, 7번째 채널은 인덱스 6입니다.
    # 임계값 이상의 픽셀을 선별하고, 나머지 픽셀을 0으로 설정합니다.
    highlighted_pixels = tf.where(channel_7 >= THRESHOLD, channel_7, 0)

    # 선별된 픽셀 값을 최대 픽셀 값으로 확장합니다.
    # 선별된 픽셀들에 대해 (픽셀 값 - 임계값)을 계산하여 범위를 [0, MAX_PIXEL_VALUE]로 매핑합니다.
    highlighted_pixels_scaled = tf.where(highlighted_pixels > 0, ((highlighted_pixels - THRESHOLD) / (MAX_PIXEL_VALUE - THRESHOLD)) * MAX_PIXEL_VALUE, 0)

    # 엣지 추출
    edge_features = Conv2D(1, (4, 4), padding='same', activation='sigmoid')(highlighted_pixels_scaled)

    # 이진화
    def binarize(x):
        return K.cast(K.greater(x, 0.5), K.floatx())  # 임계값을 0.5로 설정

    binarized_edges = Lambda(binarize)(edge_features)

    # 정규화
    normalized_edges = BatchNormalization()(binarized_edges)

    # 정규화된 엣지 맵을 세그멘테이션 결과에 더합니다.
    segmentation_result_upsampled = UpSampling2D(size=(4, 4))(segmentation_result)  # 64x64에서 256x256으로 업샘플링
    enhanced_segmentation = Add()([segmentation_result_upsampled, normalized_edges])

    return enhanced_segmentation

def create_final_model(input_shape, initial_channels, dim, num_heads):
    # 입력 텐서를 정의합니다.
    input_tensor = Input(shape=input_shape)
    
    # Stem and downsampling layers
    x = create_stem_layer(input_shape)(input_tensor)
    
    # Stages
    # We create the stages by calling them with the output tensor from the previous layer.
    stage1_output = create_stage(x, initial_channels, dim, num_heads)
    DS_PE2_output = create_downsampling_and_positional_embedding((input_shape[0]//4, input_shape[1]//4), initial_channels*2)(stage1_output)
    stage2_output = create_stage(DS_PE2_output, initial_channels*2, dim*2, num_heads*2)
    DS_PE3_output = create_downsampling_and_positional_embedding((input_shape[0]//8, input_shape[1]//8), initial_channels*4)(stage2_output)
    stage3_output = create_stage(DS_PE3_output, initial_channels*4, dim*4, num_heads*4)
    DS_PE4_output = create_downsampling_and_positional_embedding((input_shape[0]//16, input_shape[1]//16), initial_channels*8)(stage3_output)
    stage4_output = create_stage(DS_PE4_output, initial_channels*8, dim*8, num_heads*8)
        
    # Decoder to get the segmentation map
    segmentation_result = create_decoder(stage1_output, stage2_output, stage3_output, stage4_output)
    
    # Edge enhancement
    enhanced_segmentation_output = edge_enhancement(input_tensor, segmentation_result)
    
    # Final model
    final_model = Model(inputs=input_tensor, outputs=enhanced_segmentation_output)
    
    return final_model

# %%
class DataGenerator(Sequence):
    def __init__(self, img_paths, mask_paths, batch_size=32, default_path=None, augment=False, add_noise=False, noise_factor=0.01, shuffle=True):
        self.img_paths = img_paths
        self.mask_paths = mask_paths
        self.batch_size = batch_size
        self.default_path = default_path if default_path else ""
        self.augment = augment
        self.add_noise = add_noise
        self.noise_factor = noise_factor
        self.shuffle = shuffle

        if self.shuffle:
            self.on_epoch_end()

    def __len__(self):
        return len(self.img_paths) // self.batch_size

    def __getitem__(self, idx):
        batch_img_paths = self.img_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_mask_paths = self.mask_paths[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_imgs = []
        batch_masks = []

        for img_path, mask_path in zip(batch_img_paths, batch_mask_paths):
            img = tifffile.imread(os.path.join(self.default_path, img_path))
            mask = tifffile.imread(os.path.join(self.default_path, mask_path))

            # 이미지 전처리
            if self.augment:
                img, mask = self.augment_image(img, mask)

            img = img.astype(np.float32) / MAX_PIXEL_VALUE
            mask = mask.astype(np.float32)
            mask = np.expand_dims(mask, axis=-1)

            batch_imgs.append(img)
            batch_masks.append(mask)
        return np.array(batch_imgs), np.array(batch_masks)

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.img_paths))
            np.random.shuffle(indices)
            self.img_paths = np.array(self.img_paths)[indices].tolist()
            self.mask_paths = np.array(self.mask_paths)[indices].tolist()

    def augment_image(self, img, mask):
        decision_flip_lr = tf.random.uniform([], seed=SEED) < 0.25
        decision_flip_ud = tf.random.uniform([], seed=SEED) > 0.75
        decision_noise = tf.random.uniform([], seed=SEED) < 0.1

        if decision_flip_lr:
            img = np.flip(img, axis=1)
            mask = np.flip(mask, axis=1)

        if decision_flip_ud:
            img = np.flip(img, axis=0)
            mask = np.flip(mask, axis=0)

        # 노이즈 추가 부분도 동일한 방식으로 랜덤 결정을 시드와 함께 사용
        if self.add_noise and decision_noise:
            img = self.add_gaussian_noise(img, self.noise_factor)

        return img, mask

    
    def shuffle_lists(self, images_path, masks_path, random_state=None):
        # random_state가 주어진 경우, 난수 생성기의 시드를 설정합니다.
        if random_state is not None:
            random.seed(random_state)
        
        # images_path와 masks_path 리스트를 함께 섞기 위해 두 리스트의 쌍을 만듭니다.
        paired_lists = list(zip(images_path, masks_path))
        random.shuffle(paired_lists)
        
        # 섞인 리스트를 다시 분리합니다.
        shuffled_images_path, shuffled_masks_path = zip(*paired_lists)
        
        # zip() 함수는 튜플을 반환하므로, 리스트로 변환해 반환합니다.
        return list(shuffled_images_path), list(shuffled_masks_path)


    def add_gaussian_noise(self, image, mean=0, std=0.01, noise_factor=0.1):
        """
        이미지에 가우시안 노이즈를 추가하는 함수.
        mean: 노이즈의 평균값
        std: 노이즈의 표준편차
        noise_factor: 노이즈의 전체적인 강도를 조절하는 계수
        """
        gaussian_noise = np.random.normal(mean, std, image.shape) * noise_factor * MAX_PIXEL_VALUE
        noisy_image = image + gaussian_noise
        noisy_image = np.clip(noisy_image, 0, MAX_PIXEL_VALUE)  # 픽셀 값을 0과 MAX_PIXEL_VALUE 사이로 제한
        return noisy_image
    
def lr_decay(epoch, lr):
    """
    에포크에 따라 학습률을 감소시키는 함수.
    매 epoch마다 학습률을 0.95배 해주는 예시.
    """
    new_lr = lr * LEARNING_RATE_DECAY
    logging.info(f"Learning rate : {new_lr}")
    return new_lr

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + tf.keras.backend.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

class IoU(tf.keras.metrics.Metric):
    def __init__(self, name='iou', **kwargs):
        super(IoU, self).__init__(name=name, **kwargs)
        self.intersection = self.add_weight(name="intersection", initializer="zeros")
        self.union = self.add_weight(name="union", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(y_pred)  # 세그멘테이션 마스크를 이진 형태로 변환
        intersection = tf.reduce_sum(y_true * y_pred)
        union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
        
        # 이전 상태에 누적
        self.intersection.assign_add(intersection)
        self.union.assign_add(union)

    def result(self):
        return self.intersection / (self.union + tf.keras.backend.epsilon())

    def reset_states(self):
        # 에포크가 끝날 때마다 상태 초기화
        self.intersection.assign(0)
        self.union.assign(0)

class LoggingCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        # IoU 값을 로그에 포함시키기 위해 'iou'와 'val_iou' 키를 로그에서 검색
        # 키가 없는 경우 None을 반환하기 위해 get 메소드 사용
        iou = logs.get('iou')
        val_iou = logs.get('val_iou')
        # IoU 값이 제공되는 경우 로그 메시지에 포함, 그렇지 않은 경우 "N/A"로 표시
        logging.info(f"Epoch {epoch + 1}, Loss: {logs['loss']}, Accuracy: {logs['accuracy']}, Val_Loss: {logs['val_loss']}, Val_Accuracy: {logs['val_accuracy']}, IoU: {iou if iou is not None else 'N/A'}, Val_IoU: {val_iou if val_iou is not None else 'N/A'}")

def dice_loss_function(y_true, y_pred):
    smooth = 1e-6
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def dice_coef(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return (numerator + 1) / (denominator + 1)

def combined_dice_crossentropy_loss(y_true, y_pred):
    dice_loss = dice_loss_function(y_true, y_pred)  # 앞서 정의한 dice_loss_function 사용
    cross_entropy_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice_loss + cross_entropy_loss

def focal_loss(gamma=2., alpha=.25):
    def focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) - K.sum((1-alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss_fixed

def tversky_loss(beta):
    def loss(y_true, y_pred):
        numerator = K.sum(y_true * y_pred, axis=-1)
        denominator = y_true * y_pred + beta * (1 - y_true) * y_pred + (1 - beta) * y_true * (1 - y_pred)
        return 1 - (numerator + 1) / (K.sum(denominator, axis=-1) + 1)
    return loss

# 두 샘플 간의 유사성 metric
def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
    return dice

# 이미지 경로에서 이미지를 읽어와 정규화한 후 numpy 배열로 반환
def get_img_arr(path):
    img = rasterio.open(path).read().transpose((1, 2, 0))
    img = np.float32(img)/MAX_PIXEL_VALUE

    return img

# 마스크 이미지 경로에서 이미지를 읽어와 numpy 배열로 반환
def get_mask_arr(path):
    img = rasterio.open(path).read().transpose((1, 2, 0))
    seg = np.float32(img)
    return seg

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Training

# %%
#------------------------new------------------------
ADD_NOISE = False
NOISE_FACTOR=0.1
LOSS=combined_dice_crossentropy_loss,
METRICS = [IoU(), 'accuracy', F1Score(), dice_coef]
#---------------------------------------------------


# 변수 로그에 기록
logging.info(f'Save name: {save_name}')
logging.info(f'Number of filters: {N_FILTERS}')
logging.info(f'Number of channels: {N_CHANNELS}')
logging.info(f'Epochs: {EPOCHS}')
logging.info(f'Batch size: {BATCH_SIZE}')
logging.info(f'Image size: {IMAGE_SIZE}')
logging.info(f'Model name: {MODEL_NAME}')
logging.info(f'Initial epoch: {INITIAL_EPOCH}')
logging.info(f'Workers: {WORKERS}')
logging.info(f'Learning rate decay: {LEARNING_RATE_DECAY}')
logging.info(f'Start learning rate: {START_LARNING_RATE}')
logging.info(f'Seed: {SEED}')

# train : val = 8 : 2 나누기
x_tr, x_val = train_test_split(train_meta, test_size=0.2, random_state=SEED)
print(len(x_tr), len(x_val))

# train : val 지정 및 generator
images_train = [os.path.join(IMAGES_PATH, image) for image in x_tr['train_img'] ]
masks_train = [os.path.join(MASKS_PATH, mask) for mask in x_tr['train_mask'] ]

images_validation = [os.path.join(IMAGES_PATH, image) for image in x_val['train_img'] ]
masks_validation = [os.path.join(MASKS_PATH, mask) for mask in x_val['train_mask'] ]

# 학습 데이터용 인스턴스 생성, 데이터 증강 적용
train_generator = DataGenerator(images_train, masks_train, batch_size=BATCH_SIZE, default_path=IMAGES_PATH, augment=AUGMENT,add_noise=ADD_NOISE, noise_factor=NOISE_FACTOR)
# 검증 데이터용 인스턴스 생성, 데이터 증강 미적용
validation_generator = DataGenerator(images_validation, masks_validation, batch_size=BATCH_SIZE, default_path=IMAGES_PATH, augment=False, add_noise=False)

# 최종 모델 생성
final_model = create_final_model(input_shape, initial_channels, dim, num_heads)
# 모델 컴파일
final_model.compile(optimizer=Adam(learning_rate=START_LARNING_RATE),
                    loss=LOSS,
                    metrics=METRICS)

# 콜백 정의
es = EarlyStopping(monitor='val_iou', mode='max', verbose=1, patience=EARLY_STOP_PATIENCE)
checkpoint = ModelCheckpoint(os.path.join(OUTPUT_DIR, CHECKPOINT_MODEL_NAME), 
                             monitor='val_iou',
                             verbose=1, save_best_only=True, mode='max', save_freq='epoch')
lr_scheduler = LearningRateScheduler(lr_decay)

# 콜백에 Pruning 콜백 추가
callbacks = [
    checkpoint,
    es,
    lr_scheduler,
    LoggingCallback()
]

# 모델 훈련
history = final_model.fit(
    train_generator,
    steps_per_epoch=len(images_train) // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=len(images_validation) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[checkpoint, es, lr_scheduler, LoggingCallback()],
    workers=WORKERS,
    initial_epoch=INITIAL_EPOCH
)

# 필요 시 final_model 저장
logging.info('가중치 저장')
model_weights_output = os.path.join(OUTPUT_DIR, FINAL_WEIGHTS_OUTPUT)
final_model.save(model_weights_output)
logging.info(f"저장된 가중치 명: {model_weights_output}")
# Out:
# 26860 6715
# Epoch 1/30
# 2024-03-24 05:10:24.332803: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-24 05:10:24.332835: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2024-03-24 05:10:24.332935: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.364014: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2024-03-24 05:10:24.427978: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.429204: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.429250: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.429605: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.430558: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.430736: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.431263: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.431355: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.431580: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:24.459186: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-24 05:10:27.259675: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.304115: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.304147: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.304779: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.305167: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.305204: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.305656: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.305700: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.307510: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:27.452719: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-03-24 05:10:37.487282: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 32.00GiB (rounded to 34359738368)requested by op model/sequential_1/sequential_2/emsa_block/MatMul
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-24 05:10:37.487368: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-24 05:10:37.487388: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 205, Chunks in use: 205. 51.2KiB allocated for chunks. 51.2KiB in use in bin. 20.1KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487399: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 75, Chunks in use: 75. 38.5KiB allocated for chunks. 38.5KiB in use in bin. 37.5KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487410: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 136, Chunks in use: 136. 139.0KiB allocated for chunks. 139.0KiB in use in bin. 136.0KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487419: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 119, Chunks in use: 119. 241.5KiB allocated for chunks. 241.5KiB in use in bin. 238.0KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487428: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-24 05:10:37.487439: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 33.8KiB allocated for chunks. 33.8KiB in use in bin. 33.8KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487448: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 12, Chunks in use: 12. 195.0KiB allocated for chunks. 195.0KiB in use in bin. 192.0KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487457: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 8, Chunks in use: 8. 384.0KiB allocated for chunks. 384.0KiB in use in bin. 384.0KiB client-requested in use in bin.
# 2024-03-24 05:10:37.487466: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 56, Chunks in use: 56. 4.02MiB allocated for chunks. 4.02MiB in use in bin. 3.80MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487474: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 48, Chunks in use: 48. 6.88MiB allocated for chunks. 6.88MiB in use in bin. 6.60MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487484: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 59, Chunks in use: 59. 16.41MiB allocated for chunks. 16.41MiB in use in bin. 16.16MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487493: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 34, Chunks in use: 33. 17.25MiB allocated for chunks. 16.50MiB in use in bin. 16.38MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487502: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 32, Chunks in use: 32. 32.62MiB allocated for chunks. 32.62MiB in use in bin. 32.38MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487513: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 3, Chunks in use: 3. 7.50MiB allocated for chunks. 7.50MiB in use in bin. 7.50MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487521: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 5, Chunks in use: 5. 26.56MiB allocated for chunks. 26.56MiB in use in bin. 21.50MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487526: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-24 05:10:37.487529: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 4, Chunks in use: 4. 64.00MiB allocated for chunks. 64.00MiB in use in bin. 64.00MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487532: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 1, Chunks in use: 0. 47.12MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-24 05:10:37.487536: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 8, Chunks in use: 8. 514.58MiB allocated for chunks. 514.58MiB in use in bin. 512.00MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487545: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 3, Chunks in use: 2. 544.00MiB allocated for chunks. 352.00MiB in use in bin. 288.00MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487548: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 2.81GiB allocated for chunks. 892.00MiB in use in bin. 768.00MiB client-requested in use in bin.
# 2024-03-24 05:10:37.487552: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 32.00GiB was 256.00MiB, Chunk State:
# 2024-03-24 05:10:37.487558: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 1.94GiB | Requested Size: 64.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 64.00MiB | Requested Size: 64.00MiB | in_use: 1 | bin_num: -1
# 2024-03-24 05:10:37.487561: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2024-03-24 05:10:37.487565: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb03a000000 of size 67108864 next 809
# 2024-03-24 05:10:37.487568: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb03e000000 of size 2080374784 next 18446744073709551615
# 2024-03-24 05:10:37.487571: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1073741824
# 2024-03-24 05:10:37.487574: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0ba000000 of size 536870912 next 806
# 2024-03-24 05:10:37.487577: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0da000000 of size 67108864 next 789
# 2024-03-24 05:10:37.487579: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0de000000 of size 67108864 next 801
# 2024-03-24 05:10:37.487582: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0e2000000 of size 67108864 next 811
# 2024-03-24 05:10:37.487585: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0e6000000 of size 67108864 next 812
# 2024-03-24 05:10:37.487587: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0ea000000 of size 67108864 next 814
# 2024-03-24 05:10:37.487590: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb0ee000000 of size 201326592 next 18446744073709551615
# 2024-03-24 05:10:37.487592: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 536870912
# 2024-03-24 05:10:37.487595: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0fa000000 of size 4194304 next 805
# 2024-03-24 05:10:37.487599: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb0fa400000 of size 134217728 next 804
# 2024-03-24 05:10:37.487602: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb102400000 of size 398458880 next 18446744073709551615
# 2024-03-24 05:10:37.487605: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 268435456
# 2024-03-24 05:10:37.487608: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb11a000000 of size 16777216 next 797
# 2024-03-24 05:10:37.487611: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb11b000000 of size 16777216 next 808
# 2024-03-24 05:10:37.487614: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb11c000000 of size 234881024 next 18446744073709551615
# 2024-03-24 05:10:37.487616: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 268435456
# 2024-03-24 05:10:37.487619: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce000000 of size 4718592 next 585
# 2024-03-24 05:10:37.487621: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce480000 of size 2048 next 586
# 2024-03-24 05:10:37.487624: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce480800 of size 2048 next 587
# 2024-03-24 05:10:37.487627: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce481000 of size 131072 next 588
# 2024-03-24 05:10:37.487629: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce4a1000 of size 131072 next 589
# 2024-03-24 05:10:37.487633: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce4c1000 of size 131072 next 590
# 2024-03-24 05:10:37.487636: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce4e1000 of size 131072 next 591
# 2024-03-24 05:10:37.487639: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce501000 of size 2048 next 592
# 2024-03-24 05:10:37.487641: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce501800 of size 2048 next 593
# 2024-03-24 05:10:37.487644: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce502000 of size 2048 next 594
# 2024-03-24 05:10:37.487646: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce502800 of size 2048 next 595
# 2024-03-24 05:10:37.487649: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce503000 of size 2048 next 596
# 2024-03-24 05:10:37.487652: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce503800 of size 2048 next 597
# 2024-03-24 05:10:37.487654: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce504000 of size 2048 next 598
# 2024-03-24 05:10:37.487657: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce504800 of size 2048 next 599
# 2024-03-24 05:10:37.487659: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce505000 of size 393216 next 600
# 2024-03-24 05:10:37.487662: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce565000 of size 393216 next 601
# 2024-03-24 05:10:37.487665: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce5c5000 of size 1048576 next 602
# 2024-03-24 05:10:37.487667: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce6c5000 of size 1048576 next 603
# 2024-03-24 05:10:37.487670: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce7c5000 of size 2048 next 604
# 2024-03-24 05:10:37.487673: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce7c5800 of size 2048 next 605
# 2024-03-24 05:10:37.487675: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce7c6000 of size 524288 next 606
# 2024-03-24 05:10:37.487678: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce846000 of size 524288 next 607
# 2024-03-24 05:10:37.487681: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce8c6000 of size 1024 next 608
# 2024-03-24 05:10:37.487684: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce8c6400 of size 1024 next 609
# 2024-03-24 05:10:37.487698: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce8c6800 of size 524288 next 610
# 2024-03-24 05:10:37.487700: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce946800 of size 524288 next 611
# 2024-03-24 05:10:37.487703: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c6800 of size 2048 next 612
# 2024-03-24 05:10:37.487705: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c7000 of size 2048 next 613
# 2024-03-24 05:10:37.487708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c7800 of size 2048 next 614
# 2024-03-24 05:10:37.487711: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c8000 of size 2048 next 615
# 2024-03-24 05:10:37.487713: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c8800 of size 2048 next 616
# 2024-03-24 05:10:37.487716: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c9000 of size 2048 next 617
# 2024-03-24 05:10:37.487718: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9c9800 of size 2048 next 618
# 2024-03-24 05:10:37.487721: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9ca000 of size 2048 next 619
# 2024-03-24 05:10:37.487723: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9ca800 of size 2048 next 620
# 2024-03-24 05:10:37.487726: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9cb000 of size 2048 next 621
# 2024-03-24 05:10:37.487729: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ce9cb800 of size 393216 next 622
# 2024-03-24 05:10:37.487732: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cea2b800 of size 393216 next 623
# 2024-03-24 05:10:37.487735: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cea8b800 of size 1048576 next 624
# 2024-03-24 05:10:37.487737: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ceb8b800 of size 1048576 next 625
# 2024-03-24 05:10:37.487740: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cec8b800 of size 2048 next 626
# 2024-03-24 05:10:37.487742: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cec8c000 of size 2048 next 627
# 2024-03-24 05:10:37.487745: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cec8c800 of size 524288 next 628
# 2024-03-24 05:10:37.487748: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ced0c800 of size 524288 next 629
# 2024-03-24 05:10:37.487750: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ced8c800 of size 1024 next 630
# 2024-03-24 05:10:37.487753: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ced8cc00 of size 1024 next 631
# 2024-03-24 05:10:37.487755: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ced8d000 of size 524288 next 632
# 2024-03-24 05:10:37.487758: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee0d000 of size 524288 next 633
# 2024-03-24 05:10:37.487760: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8d000 of size 2048 next 634
# 2024-03-24 05:10:37.487763: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8d800 of size 2048 next 635
# 2024-03-24 05:10:37.487766: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8e000 of size 2048 next 636
# 2024-03-24 05:10:37.487768: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8e800 of size 2048 next 637
# 2024-03-24 05:10:37.487771: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8f000 of size 2048 next 638
# 2024-03-24 05:10:37.487774: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee8f800 of size 2048 next 639
# 2024-03-24 05:10:37.487777: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee90000 of size 2048 next 640
# 2024-03-24 05:10:37.487779: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee90800 of size 2048 next 641
# 2024-03-24 05:10:37.487782: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee91000 of size 2048 next 642
# 2024-03-24 05:10:37.487784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee91800 of size 2048 next 643
# 2024-03-24 05:10:37.487787: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cee92000 of size 393216 next 644
# 2024-03-24 05:10:37.487789: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6ceef2000 of size 393216 next 645
# 2024-03-24 05:10:37.487792: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cef52000 of size 1048576 next 646
# 2024-03-24 05:10:37.487795: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf052000 of size 1048576 next 647
# 2024-03-24 05:10:37.487797: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf152000 of size 2048 next 648
# 2024-03-24 05:10:37.487800: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf152800 of size 2048 next 649
# 2024-03-24 05:10:37.487802: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf153000 of size 524288 next 650
# 2024-03-24 05:10:37.487805: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf1d3000 of size 524288 next 651
# 2024-03-24 05:10:37.487808: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf253000 of size 1024 next 652
# 2024-03-24 05:10:37.487810: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf253400 of size 1024 next 653
# 2024-03-24 05:10:37.487813: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf253800 of size 524288 next 654
# 2024-03-24 05:10:37.487815: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf2d3800 of size 524288 next 655
# 2024-03-24 05:10:37.487819: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf353800 of size 2048 next 656
# 2024-03-24 05:10:37.487821: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf354000 of size 2048 next 657
# 2024-03-24 05:10:37.487824: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf354800 of size 2048 next 658
# 2024-03-24 05:10:37.487826: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf355000 of size 2048 next 659
# 2024-03-24 05:10:37.487829: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf355800 of size 2048 next 660
# 2024-03-24 05:10:37.487831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf356000 of size 2048 next 661
# 2024-03-24 05:10:37.487834: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf356800 of size 2048 next 662
# 2024-03-24 05:10:37.487836: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf357000 of size 2048 next 663
# 2024-03-24 05:10:37.487839: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf357800 of size 2048 next 664
# 2024-03-24 05:10:37.487842: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf358000 of size 2048 next 665
# 2024-03-24 05:10:37.487844: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf358800 of size 393216 next 666
# 2024-03-24 05:10:37.487847: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf3b8800 of size 393216 next 667
# 2024-03-24 05:10:37.487849: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf418800 of size 1048576 next 668
# 2024-03-24 05:10:37.487852: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf518800 of size 1048576 next 669
# 2024-03-24 05:10:37.487855: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf618800 of size 2048 next 670
# 2024-03-24 05:10:37.487857: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf619000 of size 2048 next 671
# 2024-03-24 05:10:37.487860: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf619800 of size 524288 next 672
# 2024-03-24 05:10:37.487862: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf699800 of size 524288 next 673
# 2024-03-24 05:10:37.487865: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf719800 of size 1024 next 674
# 2024-03-24 05:10:37.487867: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf719c00 of size 1024 next 675
# 2024-03-24 05:10:37.487870: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf71a000 of size 524288 next 676
# 2024-03-24 05:10:37.487873: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf79a000 of size 524288 next 677
# 2024-03-24 05:10:37.487875: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf81a000 of size 2048 next 678
# 2024-03-24 05:10:37.487878: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf81a800 of size 2048 next 679
# 2024-03-24 05:10:37.487881: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf81b000 of size 1048576 next 680
# 2024-03-24 05:10:37.487883: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cf91b000 of size 1048576 next 681
# 2024-03-24 05:10:37.487886: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1b000 of size 2048 next 682
# 2024-03-24 05:10:37.487888: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1b800 of size 2048 next 683
# 2024-03-24 05:10:37.487891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1c000 of size 2048 next 684
# 2024-03-24 05:10:37.487894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1c800 of size 2048 next 685
# 2024-03-24 05:10:37.487896: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1d000 of size 2048 next 686
# 2024-03-24 05:10:37.487899: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1d800 of size 2048 next 687
# 2024-03-24 05:10:37.487901: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfa1e000 of size 1048576 next 688
# 2024-03-24 05:10:37.487905: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfb1e000 of size 1048576 next 689
# 2024-03-24 05:10:37.487907: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc1e000 of size 2048 next 690
# 2024-03-24 05:10:37.487910: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc1e800 of size 2048 next 691
# 2024-03-24 05:10:37.487913: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc1f000 of size 2048 next 692
# 2024-03-24 05:10:37.487915: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc1f800 of size 2048 next 693
# 2024-03-24 05:10:37.487918: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc20000 of size 2048 next 694
# 2024-03-24 05:10:37.487920: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc20800 of size 2048 next 695
# 2024-03-24 05:10:37.487923: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfc21000 of size 1048576 next 696
# 2024-03-24 05:10:37.487926: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfd21000 of size 1048576 next 697
# 2024-03-24 05:10:37.487928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe21000 of size 2048 next 698
# 2024-03-24 05:10:37.487931: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe21800 of size 2048 next 699
# 2024-03-24 05:10:37.487933: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe22000 of size 2048 next 700
# 2024-03-24 05:10:37.487936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe22800 of size 2048 next 701
# 2024-03-24 05:10:37.487939: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe23000 of size 2048 next 702
# 2024-03-24 05:10:37.487941: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe23800 of size 2048 next 703
# 2024-03-24 05:10:37.487944: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cfe24000 of size 1048576 next 704
# 2024-03-24 05:10:37.487946: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6cff24000 of size 1048576 next 705
# 2024-03-24 05:10:37.487949: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0024000 of size 2048 next 706
# 2024-03-24 05:10:37.487952: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0024800 of size 2048 next 707
# 2024-03-24 05:10:37.487954: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0025000 of size 2048 next 708
# 2024-03-24 05:10:37.487957: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0025800 of size 2048 next 709
# 2024-03-24 05:10:37.487964: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0026000 of size 2048 next 710
# 2024-03-24 05:10:37.487967: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0026800 of size 2048 next 711
# 2024-03-24 05:10:37.487969: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0027000 of size 2621440 next 712
# 2024-03-24 05:10:37.487973: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d02a7000 of size 2621440 next 713
# 2024-03-24 05:10:37.487975: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0527000 of size 1024 next 714
# 2024-03-24 05:10:37.487978: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0527400 of size 1024 next 715
# 2024-03-24 05:10:37.487981: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0527800 of size 131072 next 716
# 2024-03-24 05:10:37.487983: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0547800 of size 131072 next 717
# 2024-03-24 05:10:37.487986: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0567800 of size 1024 next 718
# 2024-03-24 05:10:37.487988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0567c00 of size 1024 next 719
# 2024-03-24 05:10:37.487991: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0568000 of size 65536 next 720
# 2024-03-24 05:10:37.487994: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0578000 of size 65536 next 721
# 2024-03-24 05:10:37.487997: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588000 of size 1024 next 722
# 2024-03-24 05:10:37.487999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588400 of size 1024 next 723
# 2024-03-24 05:10:37.488002: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588800 of size 256 next 724
# 2024-03-24 05:10:37.488005: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588900 of size 256 next 725
# 2024-03-24 05:10:37.488007: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588a00 of size 256 next 726
# 2024-03-24 05:10:37.488010: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588b00 of size 256 next 727
# 2024-03-24 05:10:37.488013: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0588c00 of size 1024 next 728
# 2024-03-24 05:10:37.488015: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589000 of size 1024 next 729
# 2024-03-24 05:10:37.488018: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589400 of size 256 next 730
# 2024-03-24 05:10:37.488020: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589500 of size 256 next 731
# 2024-03-24 05:10:37.488023: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589600 of size 256 next 732
# 2024-03-24 05:10:37.488026: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589700 of size 256 next 733
# 2024-03-24 05:10:37.488028: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589800 of size 256 next 734
# 2024-03-24 05:10:37.488031: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589900 of size 256 next 735
# 2024-03-24 05:10:37.488033: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589a00 of size 256 next 736
# 2024-03-24 05:10:37.488036: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589b00 of size 256 next 737
# 2024-03-24 05:10:37.488039: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589c00 of size 256 next 738
# 2024-03-24 05:10:37.488041: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589d00 of size 256 next 739
# 2024-03-24 05:10:37.488044: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589e00 of size 256 next 742
# 2024-03-24 05:10:37.488047: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d0589f00 of size 256 next 745
# 2024-03-24 05:10:37.488049: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a000 of size 256 next 746
# 2024-03-24 05:10:37.488052: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a100 of size 256 next 744
# 2024-03-24 05:10:37.488054: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a200 of size 256 next 753
# 2024-03-24 05:10:37.488057: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a300 of size 256 next 741
# 2024-03-24 05:10:37.488060: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a400 of size 256 next 752
# 2024-03-24 05:10:37.488062: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a500 of size 256 next 747
# 2024-03-24 05:10:37.488065: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a600 of size 256 next 750
# 2024-03-24 05:10:37.488067: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a700 of size 256 next 755
# 2024-03-24 05:10:37.488070: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a800 of size 256 next 740
# 2024-03-24 05:10:37.488073: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058a900 of size 256 next 751
# 2024-03-24 05:10:37.488075: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058aa00 of size 256 next 749
# 2024-03-24 05:10:37.488078: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058ab00 of size 256 next 743
# 2024-03-24 05:10:37.488081: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058ac00 of size 256 next 756
# 2024-03-24 05:10:37.488083: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058ad00 of size 256 next 754
# 2024-03-24 05:10:37.488086: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058ae00 of size 256 next 771
# 2024-03-24 05:10:37.488088: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058af00 of size 256 next 757
# 2024-03-24 05:10:37.488091: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b000 of size 256 next 758
# 2024-03-24 05:10:37.488094: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b100 of size 256 next 759
# 2024-03-24 05:10:37.488096: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b200 of size 256 next 760
# 2024-03-24 05:10:37.488099: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b300 of size 256 next 794
# 2024-03-24 05:10:37.488101: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b400 of size 256 next 762
# 2024-03-24 05:10:37.488104: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b500 of size 256 next 763
# 2024-03-24 05:10:37.488107: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b600 of size 256 next 796
# 2024-03-24 05:10:37.488109: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b700 of size 256 next 802
# 2024-03-24 05:10:37.488112: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b800 of size 256 next 748
# 2024-03-24 05:10:37.488114: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058b900 of size 256 next 761
# 2024-03-24 05:10:37.488117: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058ba00 of size 256 next 770
# 2024-03-24 05:10:37.488120: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058bb00 of size 256 next 767
# 2024-03-24 05:10:37.488122: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058bc00 of size 256 next 768
# 2024-03-24 05:10:37.488125: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058bd00 of size 256 next 769
# 2024-03-24 05:10:37.488128: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058be00 of size 256 next 764
# 2024-03-24 05:10:37.488130: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058bf00 of size 256 next 773
# 2024-03-24 05:10:37.488133: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c000 of size 256 next 774
# 2024-03-24 05:10:37.488136: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c100 of size 256 next 775
# 2024-03-24 05:10:37.488138: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c200 of size 256 next 776
# 2024-03-24 05:10:37.488141: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c300 of size 256 next 777
# 2024-03-24 05:10:37.488143: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c400 of size 256 next 778
# 2024-03-24 05:10:37.488146: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c500 of size 256 next 779
# 2024-03-24 05:10:37.488149: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c600 of size 256 next 780
# 2024-03-24 05:10:37.488151: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c700 of size 256 next 781
# 2024-03-24 05:10:37.488154: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c800 of size 256 next 782
# 2024-03-24 05:10:37.488156: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d058c900 of size 262144 next 792
# 2024-03-24 05:10:37.488159: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d05cc900 of size 131072 next 793
# 2024-03-24 05:10:37.488162: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d05ec900 of size 131072 next 783
# 2024-03-24 05:10:37.488165: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d060c900 of size 524288 next 791
# 2024-03-24 05:10:37.488167: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d068c900 of size 524288 next 784
# 2024-03-24 05:10:37.488170: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d070c900 of size 256 next 765
# 2024-03-24 05:10:37.488173: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d070ca00 of size 256 next 785
# 2024-03-24 05:10:37.488175: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb6d070cb00 of size 785920 next 786
# 2024-03-24 05:10:37.488178: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d07cc900 of size 262144 next 787
# 2024-03-24 05:10:37.488181: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d080c900 of size 1310720 next 790
# 2024-03-24 05:10:37.488184: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d094c900 of size 16777216 next 795
# 2024-03-24 05:10:37.488187: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d194c900 of size 4194304 next 799
# 2024-03-24 05:10:37.488189: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d1d4c900 of size 16777216 next 798
# 2024-03-24 05:10:37.488192: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d2d4c900 of size 1048576 next 810
# 2024-03-24 05:10:37.488195: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb6d2e4c900 of size 49414400 next 807
# 2024-03-24 05:10:37.488197: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d5d6ca00 of size 67108864 next 788
# 2024-03-24 05:10:37.488200: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb6d9d6ca00 of size 69809664 next 18446744073709551615
# 2024-03-24 05:10:37.488203: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 33554432
# 2024-03-24 05:10:37.488205: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c000000 of size 1048576 next 257
# 2024-03-24 05:10:37.488208: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c100000 of size 1048576 next 8
# 2024-03-24 05:10:37.488211: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c200000 of size 1048576 next 6
# 2024-03-24 05:10:37.488213: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c300000 of size 1048576 next 264
# 2024-03-24 05:10:37.488216: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c400000 of size 1048576 next 270
# 2024-03-24 05:10:37.488218: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c500000 of size 1048576 next 275
# 2024-03-24 05:10:37.488221: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c600000 of size 294912 next 395
# 2024-03-24 05:10:37.488224: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c648000 of size 512 next 396
# 2024-03-24 05:10:37.488227: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c648200 of size 512 next 397
# 2024-03-24 05:10:37.488229: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c648400 of size 524288 next 398
# 2024-03-24 05:10:37.488232: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c6c8400 of size 524288 next 399
# 2024-03-24 05:10:37.488234: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c748400 of size 524288 next 400
# 2024-03-24 05:10:37.488237: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c7c8400 of size 524288 next 401
# 2024-03-24 05:10:37.488240: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848400 of size 512 next 402
# 2024-03-24 05:10:37.488242: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848600 of size 512 next 403
# 2024-03-24 05:10:37.488245: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848800 of size 512 next 404
# 2024-03-24 05:10:37.488247: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848a00 of size 512 next 405
# 2024-03-24 05:10:37.488250: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848c00 of size 512 next 406
# 2024-03-24 05:10:37.488253: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c848e00 of size 512 next 407
# 2024-03-24 05:10:37.488256: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c849000 of size 512 next 408
# 2024-03-24 05:10:37.488258: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c849200 of size 512 next 409
# 2024-03-24 05:10:37.488261: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c849400 of size 98304 next 410
# 2024-03-24 05:10:37.488264: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c861400 of size 98304 next 411
# 2024-03-24 05:10:37.488267: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c879400 of size 65536 next 412
# 2024-03-24 05:10:37.488270: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c889400 of size 65536 next 413
# 2024-03-24 05:10:37.488272: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c899400 of size 512 next 414
# 2024-03-24 05:10:37.488275: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c899600 of size 512 next 415
# 2024-03-24 05:10:37.488277: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c899800 of size 131072 next 416
# 2024-03-24 05:10:37.488280: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c8b9800 of size 131072 next 417
# 2024-03-24 05:10:37.488283: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c8d9800 of size 1024 next 418
# 2024-03-24 05:10:37.488285: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c8d9c00 of size 1024 next 419
# 2024-03-24 05:10:37.488288: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c8da000 of size 131072 next 420
# 2024-03-24 05:10:37.488290: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c8fa000 of size 131072 next 421
# 2024-03-24 05:10:37.488293: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91a000 of size 512 next 422
# 2024-03-24 05:10:37.488295: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91a200 of size 512 next 423
# 2024-03-24 05:10:37.488298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91a400 of size 512 next 424
# 2024-03-24 05:10:37.488301: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91a600 of size 512 next 425
# 2024-03-24 05:10:37.488303: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91a800 of size 512 next 426
# 2024-03-24 05:10:37.488306: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91aa00 of size 512 next 427
# 2024-03-24 05:10:37.488308: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91ac00 of size 512 next 428
# 2024-03-24 05:10:37.488311: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91ae00 of size 512 next 429
# 2024-03-24 05:10:37.488313: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91b000 of size 512 next 430
# 2024-03-24 05:10:37.488316: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91b200 of size 512 next 431
# 2024-03-24 05:10:37.488319: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c91b400 of size 98304 next 432
# 2024-03-24 05:10:37.488321: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c933400 of size 98304 next 433
# 2024-03-24 05:10:37.488324: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c94b400 of size 65536 next 434
# 2024-03-24 05:10:37.488326: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c95b400 of size 65536 next 435
# 2024-03-24 05:10:37.488329: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c96b400 of size 512 next 436
# 2024-03-24 05:10:37.488331: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c96b600 of size 512 next 437
# 2024-03-24 05:10:37.488334: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c96b800 of size 131072 next 438
# 2024-03-24 05:10:37.488337: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c98b800 of size 131072 next 439
# 2024-03-24 05:10:37.488339: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ab800 of size 1024 next 440
# 2024-03-24 05:10:37.488342: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9abc00 of size 1024 next 441
# 2024-03-24 05:10:37.488344: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ac000 of size 131072 next 442
# 2024-03-24 05:10:37.488347: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9cc000 of size 131072 next 443
# 2024-03-24 05:10:37.488350: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ec000 of size 512 next 444
# 2024-03-24 05:10:37.488352: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ec200 of size 512 next 445
# 2024-03-24 05:10:37.488355: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ec400 of size 512 next 446
# 2024-03-24 05:10:37.488357: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ec600 of size 512 next 447
# 2024-03-24 05:10:37.488360: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ec800 of size 512 next 448
# 2024-03-24 05:10:37.488363: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9eca00 of size 512 next 449
# 2024-03-24 05:10:37.488365: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ecc00 of size 512 next 450
# 2024-03-24 05:10:37.488368: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ece00 of size 512 next 451
# 2024-03-24 05:10:37.488370: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ed000 of size 512 next 452
# 2024-03-24 05:10:37.488373: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ed200 of size 512 next 453
# 2024-03-24 05:10:37.488376: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70c9ed400 of size 98304 next 454
# 2024-03-24 05:10:37.488378: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70ca05400 of size 98304 next 455
# 2024-03-24 05:10:37.488381: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70ca1d400 of size 65536 next 456
# 2024-03-24 05:10:37.488384: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70ca2d400 of size 65536 next 457
# 2024-03-24 05:10:37.488386: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70ca3d400 of size 512 next 458
# 2024-03-24 05:10:37.488389: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb70ca3d600 of size 512 next 459
# ...
# 2024-03-24 05:10:37.489676: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf4b2000 of size 16384 next 322
# 2024-03-24 05:10:37.489678: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf4b6000 of size 16384 next 323
# 2024-03-24 05:10:37.489681: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf4ba000 of size 65536 next 326
# 2024-03-24 05:10:37.489684: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf4ca000 of size 90112 next 195
# 2024-03-24 05:10:37.489687: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf4e0000 of size 262144 next 194
# 2024-03-24 05:10:37.489690: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf520000 of size 262144 next 197
# 2024-03-24 05:10:37.489692: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf560000 of size 262144 next 199
# 2024-03-24 05:10:37.489695: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5a0000 of size 65536 next 329
# 2024-03-24 05:10:37.489697: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5b0000 of size 65536 next 330
# 2024-03-24 05:10:37.489700: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5c0000 of size 49152 next 341
# 2024-03-24 05:10:37.489703: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5cc000 of size 49152 next 342
# 2024-03-24 05:10:37.489705: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5d8000 of size 16384 next 343
# 2024-03-24 05:10:37.489708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5dc000 of size 16384 next 344
# 2024-03-24 05:10:37.489710: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5e0000 of size 65536 next 347
# 2024-03-24 05:10:37.489713: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf5f0000 of size 65536 next 232
# 2024-03-24 05:10:37.489716: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf600000 of size 393216 next 217
# 2024-03-24 05:10:37.489718: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf660000 of size 393216 next 216
# 2024-03-24 05:10:37.489721: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf6c0000 of size 524288 next 226
# 2024-03-24 05:10:37.489723: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf740000 of size 393216 next 243
# 2024-03-24 05:10:37.489726: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7a0000 of size 65536 next 350
# 2024-03-24 05:10:37.489728: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7b0000 of size 65536 next 351
# 2024-03-24 05:10:37.489731: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7c0000 of size 49152 next 362
# 2024-03-24 05:10:37.489734: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7cc000 of size 49152 next 363
# 2024-03-24 05:10:37.489736: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7d8000 of size 16384 next 364
# 2024-03-24 05:10:37.489739: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7dc000 of size 16384 next 365
# 2024-03-24 05:10:37.489741: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7e0000 of size 65536 next 368
# 2024-03-24 05:10:37.489744: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fbbaf7f0000 of size 65536 next 18446744073709551615
# 2024-03-24 05:10:37.489747: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2024-03-24 05:10:37.489751: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 205 Chunks of size 256 totalling 51.2KiB
# 2024-03-24 05:10:37.489755: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 71 Chunks of size 512 totalling 35.5KiB
# 2024-03-24 05:10:37.489758: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 768 totalling 3.0KiB
# 2024-03-24 05:10:37.489761: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 130 Chunks of size 1024 totalling 130.0KiB
# 2024-03-24 05:10:37.489764: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1280 totalling 3.8KiB
# 2024-03-24 05:10:37.489767: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1792 totalling 5.2KiB
# 2024-03-24 05:10:37.489770: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 114 Chunks of size 2048 totalling 228.0KiB
# 2024-03-24 05:10:37.489773: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2560 totalling 2.5KiB
# 2024-03-24 05:10:37.489776: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 2816 totalling 11.0KiB
# 2024-03-24 05:10:37.489778: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 11520 totalling 33.8KiB
# 2024-03-24 05:10:37.489782: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 11 Chunks of size 16384 totalling 176.0KiB
# 2024-03-24 05:10:37.489784: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19456 totalling 19.0KiB
# 2024-03-24 05:10:37.489787: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 49152 totalling 384.0KiB
# 2024-03-24 05:10:37.489790: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 37 Chunks of size 65536 totalling 2.31MiB
# 2024-03-24 05:10:37.489793: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 73728 totalling 144.0KiB
# 2024-03-24 05:10:37.489796: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 81920 totalling 240.0KiB
# 2024-03-24 05:10:37.489799: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 90112 totalling 88.0KiB
# 2024-03-24 05:10:37.489802: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 98304 totalling 1.12MiB
# 2024-03-24 05:10:37.489805: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 125952 totalling 123.0KiB
# 2024-03-24 05:10:37.489808: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 33 Chunks of size 131072 totalling 4.12MiB
# 2024-03-24 05:10:37.489811: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 163840 totalling 160.0KiB
# 2024-03-24 05:10:37.489814: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 166912 totalling 163.0KiB
# 2024-03-24 05:10:37.489817: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 196608 totalling 2.25MiB
# 2024-03-24 05:10:37.489820: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 196864 totalling 192.2KiB
# 2024-03-24 05:10:37.489823: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 44 Chunks of size 262144 totalling 11.00MiB
# 2024-03-24 05:10:37.489826: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 294912 totalling 864.0KiB
# 2024-03-24 05:10:37.489829: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 11 Chunks of size 393216 totalling 4.12MiB
# 2024-03-24 05:10:37.489832: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 458240 totalling 447.5KiB
# 2024-03-24 05:10:37.489835: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 33 Chunks of size 524288 totalling 16.50MiB
# 2024-03-24 05:10:37.489838: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 28 Chunks of size 1048576 totalling 28.00MiB
# 2024-03-24 05:10:37.489841: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1179648 totalling 3.38MiB
# 2024-03-24 05:10:37.489844: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1310720 totalling 1.25MiB
# 2024-03-24 05:10:37.489847: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2621440 totalling 7.50MiB
# 2024-03-24 05:10:37.489850: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 4194304 totalling 8.00MiB
# 2024-03-24 05:10:37.489852: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4718592 totalling 4.50MiB
# 2024-03-24 05:10:37.489855: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7340032 totalling 7.00MiB
# 2024-03-24 05:10:37.489858: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7407616 totalling 7.06MiB
# 2024-03-24 05:10:37.489861: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 16777216 totalling 64.00MiB
# 2024-03-24 05:10:37.489864: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 67108864 totalling 448.00MiB
# 2024-03-24 05:10:37.489867: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 69809664 totalling 66.58MiB
# 2024-03-24 05:10:37.489870: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 134217728 totalling 128.00MiB
# 2024-03-24 05:10:37.489873: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 234881024 totalling 224.00MiB
# 2024-03-24 05:10:37.489876: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 398458880 totalling 380.00MiB
# 2024-03-24 05:10:37.489879: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 536870912 totalling 512.00MiB
# 2024-03-24 05:10:37.489882: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 1.89GiB
# 2024-03-24 05:10:37.489885: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 4359979008 memory_limit_: 13203406848 available bytes: 8843427840 curr_region_allocation_bytes_: 4294967296
# 2024-03-24 05:10:37.489892: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     13203406848
# InUse:                      2028077312
# MaxInUse:                   2494106112
# NumAllocs:                        6797
# MaxAllocSize:                754988800
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-24 05:10:37.489904: W tensorflow/tsl/framework/bfc_allocator.cc:497] **_______________________________________________*********************___***********xx*****x********
# 2024-03-24 05:10:37.489927: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at matmul_op_impl.h:908 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,8,4096,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [21], in <cell line: 61>()
#      53 callbacks = [
#      54     checkpoint,
#      55     es,
#      56     lr_scheduler,
#      57     LoggingCallback()
#      58 ]
#      60 # 모델 훈련
# ---> 61 history = final_model.fit(
#      62     train_generator,
#      63     steps_per_epoch=len(images_train) // BATCH_SIZE,
#      64     validation_data=validation_generator,
#      65     validation_steps=len(images_validation) // BATCH_SIZE,
#      66     epochs=EPOCHS,
#      67     callbacks=[checkpoint, es, lr_scheduler, LoggingCallback()],
#      68     workers=WORKERS,
#      69     initial_epoch=INITIAL_EPOCH
#      70 )
#      72 # 필요 시 final_model 저장
#      73 logging.info('가중치 저장')
#
# File ~/anaconda3/envs/aispark/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# RuntimeError: pybind11::error_already_set: MISMATCH of original and normalized active exception types: ORIGINAL ResourceExhaustedError REPLACED BY KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/framework/errors_impl.py(377): __init__
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/execute.py(60): quick_execute
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/context.py(1479): call_function
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py(252): __call__
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py(217): flat_call
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py(1264): _call_flat
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py(139): call_function
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py(904): _call
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py(831): __call__
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py(150): error_handler
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/keras/src/engine/training.py(1783): fit
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py(65): error_handler
#   /tmp/ipykernel_1518755/641670225.py(61): <cell line: 61>
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/interactiveshell.py(3398): run_code
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/interactiveshell.py(3338): run_ast_nodes
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/interactiveshell.py(3135): run_cell_async
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/async_helpers.py(129): _pseudo_sync_runner
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/interactiveshell.py(2936): _run_cell
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/IPython/core/interactiveshell.py(2881): run_cell
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/zmqshell.py(528): run_cell
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/ipkernel.py(383): do_execute
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/kernelbase.py(730): execute_request
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/kernelbase.py(406): dispatch_shell
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/kernelbase.py(499): process_one
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/kernelbase.py(510): dispatch_queue
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/asyncio/events.py(80): _run
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/asyncio/base_events.py(1905): _run_once
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/asyncio/base_events.py(601): run_forever
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/tornado/platform/asyncio.py(205): start
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel/kernelapp.py(712): start
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/traitlets/config/application.py(1075): launch_instance
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/site-packages/ipykernel_launcher.py(17): <module>
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/runpy.py(87): _run_code
#   /home/jskim/anaconda3/envs/aispark/lib/python3.9/runpy.py(197): _run_module_as_main

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Make Pickle , Submit format

# %%
# 제출용 pkl 파일 만들기
final_model = create_final_model(input_shape, initial_channels, dim, num_heads)
final_model.compile(optimizer = Adam(), loss = LOSS, metrics = ['accuracy'])
final_model.summary()

final_model.load_weights('model_{}_{}_final_weights.h5'.format(MODEL_NAME, save_name))

y_pred_dict = {}

# 가정: test_meta는 테스트 이미지 파일명을 포함하는 딕셔너리나 리스트입니다.
for i in test_meta['test_img']:  # tqdm은 진행 상태 바를 표시합니다.
    img = get_img_arr(f'/home/jskim/aispark/AIspark_dataset/test_img/{i}')
    y_pred = model.predict(np.array([img]), batch_size=1)

    y_pred = np.where(y_pred[0, :, :, 0] > 0.25, 1, 0)  # 임계값 처리
    y_pred = y_pred.astype(np.uint8)
    y_pred_dict[i] = y_pred

joblib.dump(y_pred_dict, '/home/jskim/aispark/y_pred_{}_{}.pkl'.format(MODEL_NAME, save_name))
# Out:
# "\n    optimizer = torch.optim.SGD([{'params':\n                                      filter(lambda p: p.requires_grad,\n                                             model.parameters()),\n                                      'lr': args2.lr}],\n                                    lr=args2.lr,\n                                    momentum=0.9,\n                                    weight_decay=0.0005,\n                                    nesterov=False,\n                                    )\n\n    optimizer = torch.optim.AdamW([{'params':\n                                      filter(lambda p: p.requires_grad,\n                                             model.parameters()),\n                                  'lr': args2.lr}],\n                                lr=args2.lr,\n                                betas=(0.9, 0.999),\n                                weight_decay=0.01,\n                                )\n"

# %% [markdown]
# ---------------------------------------
# <br><br>
#
# > * ### Visualization

# %%
# 특정 이미지에 대한 예측 마스크 시각화 함수
def visualize_prediction(test_image_name):
    # 테스트 이미지 로딩
    img = get_img_arr(f'./AIspark_dataset/test_img/{test_image_name}')
    
    # 예측된 마스크 로딩
    y_pred = y_pred_dict[test_image_name]
    
    # 이미지와 예측된 마스크 시각화
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    axs[0].imshow(img[:, :, 0], cmap='gray')  # 첫 번째 채널을 그레이스케일 이미지로 시각화
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    axs[1].imshow(y_pred, cmap='gray')  # 예측된 마스크 시각화
    axs[1].set_title('Predicted Mask')
    axs[1].axis('off')

    plt.show()

def load_tif_image(image_path):
    with rasterio.open(image_path) as img_file:
        img = img_file.read()
    return np.transpose(img, (1, 2, 0))

def visualize_channel_images(image):
    channels = image.shape[2]
    plt.figure(figsize=(20, 10))
    for i in range(channels):
        plt.subplot(2, (channels+1)//2, i+1)
        plt.imshow(image[:, :, i])
        plt.title(f'Channel {i+1}')
        plt.axis('off')
    plt.show()

# 시각화
# 예측 결과 딕셔너리 로드
y_pred_dict = joblib.load('/home/jskim/aispark/y_pred_{}_{}.pkl'.format(MODEL_NAME, save_name))

# 예시: 'test_img_2427.tif' 이미지에 대한 예측 마스크 시각화
visualize_prediction('test_img_2423.tif')
image_path = '/home/jskim/aispark/AIspark_dataset/test_img/test_img_2423.tif'
visualize_channel_images(load_tif_image(image_path))
